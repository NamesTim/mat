# %%
# !pip install PyPDF2
# Out:
# ...
#   Obtaining dependency information for PyPDF2 from https://files.pythonhosted.org/packages/8e/5e/c86a5643653825d3c913719e788e41386bee415c2b87b4f955432f2de6b2/pypdf2-3.0.1-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 12.9 MB/s eta 0:00:00
# ...

# %%
#we'll use this class to extract text from our pdf
from PyPDF2 import PdfReader

# %%
matatu_pdf=PdfReader('./sacco and routes/ntsa-matatu-saccos.pdf')
print(type(matatu_pdf))
# Out:
# <class 'PyPDF2._reader.PdfReader'>

# %%
#try a sample with page 1 
page1=matatu_pdf.pages[0]
print(type(page1))
# Out:
# <class 'PyPDF2._page.PageObject'>

# %%
page1_text=page1.extract_text()

# %%
#as you can see the output is not readily usable, let's fix that.
print(type(page1_text))
# Out:
# <class 'str'>
